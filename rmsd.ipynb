# %% [markdown]
# # RMSD of predicted to solved structures
# run prior to generating alignments in order to confirm fidelity of TCRDock predictions

# %% [markdown]
# ### input file setup

# %%
# Generates input .tsv files to for setup.sh in /scripts 

import os
import pandas as pd

# === Constants ===
solved_meta_file = "/home/ggrama/tcrgen/compiled_solved_metadata.csv" # experimentally solved structure information
output_dir = "/scratch/ggrama/tcrgen/solved/user_targets" # write to scratch
organism = 'human'
mhc_class = 1
mhc = 'A*02:01'
required_cols = {'Peptide', 'TRAV', 'TRAJ', 'CDR3α', 'TRBV', 'TRBJ', 'CDR3β'}

# === Load solved metadata ===
solved_meta = pd.read_csv(solved_meta_file)
solved_meta = solved_meta.set_index("ID")
os.makedirs(output_dir, exist_ok=True)

# === Iterate through all entries ===
for solved_id, row in solved_meta.iterrows():
    if any(pd.isna(row[col]) or str(row[col]).strip() == "" for col in required_cols):
        print(f"Skipping {solved_id} — missing required fields")
        continue

    target = pd.DataFrame([dict(
        organism=organism,
        mhc_class=mhc_class,
        mhc=mhc,
        peptide=row['Peptide'],
        va=row['TRAV'],
        ja=row['TRAJ'],
        cdr3a=row['CDR3α'],
        vb=row['TRBV'],
        jb=row['TRBJ'],
        cdr3b=row['CDR3β']
    )])

    outpath = os.path.join(output_dir, f"{solved_id}.tsv")

    try:
        target.to_csv(outpath, sep="\t", index=False)
        print(f"Wrote: {outpath}")
    except Exception as e:
        print(f"Failed to write {outpath}: {e}")
# Out:
# Wrote: /scratch/ggrama/tcrgen/solved/user_targets/2vlj.tsv
# Wrote: /scratch/ggrama/tcrgen/solved/user_targets/2vlk.tsv
# Wrote: /scratch/ggrama/tcrgen/solved/user_targets/2vlr.tsv
# Wrote: /scratch/ggrama/tcrgen/solved/user_targets/5isz.tsv
# Wrote: /scratch/ggrama/tcrgen/solved/user_targets/1oga.tsv
# Wrote: /scratch/ggrama/tcrgen/solved/user_targets/5euo.tsv

# %%
# writes .tsv paths to .txt file which will be read by setup.sh

from pathlib import Path

# === Config ===
ROOT_DIR = Path("/scratch/ggrama/tcrgen")
OUTPUT_FILE = Path("/home/ggrama/tcrgen/scripts/tsv_paths.txt") # input file in setup.sh, change path

# === Remove old output file if it exists
OUTPUT_FILE.unlink(missing_ok=True)

# === Search for all .tsv files under user_targets/
tsv_files = list(ROOT_DIR.rglob("*/user_targets/*.tsv"))
missing = []

for tsv_path in tsv_files:
    if ".ipynb_checkpoints" in str(tsv_path):
        continue

    basename = tsv_path.stem
    parent_dir = tsv_path.parent
    expected_targets_tsv = parent_dir.parent / "user_outputs" / basename / "targets.tsv"

    if not expected_targets_tsv.exists():
        missing.append(str(tsv_path))

# === Write missing paths to file
if missing:
    OUTPUT_FILE.parent.mkdir(parents=True, exist_ok=True)
    with open(OUTPUT_FILE, "w") as f:
        f.write("\n".join(missing))
    print(f"❌ Missing targets.tsv files listed in: {OUTPUT_FILE}")
    print(f"Count: {len(missing)}")
else:
    print("✅ All user_outputs/…/targets.tsv files present.")

# sbatch scripts/setup.sh
# Out:
# ✅ All user_outputs/…/targets.tsv files present.

# %% [markdown]
# ### TCRDock prediction setup

# %%
# writes targets.tsv paths to .txt file which will be read by predict.sh

from pathlib import Path

# === Config ===
ROOT_DIR = Path("/scratch/ggrama/tcrgen")
OUTPUT_FILE = Path("/home/ggrama/tcrgen/scripts/targets_paths.txt")

# === Remove old file if it exists ===
OUTPUT_FILE.unlink(missing_ok=True)

# === Locate all targets.tsv files ===
targets_files = list(ROOT_DIR.rglob("targets.tsv"))
missing = []

for targets_path in targets_files:
    if ".ipynb_checkpoints" in str(targets_path):
        continue

    user_outputs_dir = targets_path.parent
    target_name = user_outputs_dir.name.strip()
    base_dir = user_outputs_dir.parent.parent
    predictions_dir = base_dir / "predictions" / target_name

    if not any(predictions_dir.glob("*.pdb")):
        missing.append(targets_path)

# === Save missing targets.tsv paths ===
if missing:
    OUTPUT_FILE.parent.mkdir(parents=True, exist_ok=True)
    with open(OUTPUT_FILE, "w") as f:
        for path in missing:
            f.write(str(path) + "\n")
    print(f"Missing .pdb count: {len(missing)}")
else:
    print("All prediction outputs present.")

#sbatch predict.sh
# Out:
# All prediction outputs present.

# %% [markdown]
# ### inputs for relax.sh

# %%
from pathlib import Path
from collections import defaultdict

# === Constants ===
TCRGEN_ROOT = Path("/scratch/ggrama/tcrgen/solved")
OUTPUT_FILE = Path("/home/ggrama/tcrgen/scripts/pdb_paths.txt")

# === Step 1: Gather all predicted pdbs
predicted_pdbs = list(TCRGEN_ROOT.glob("**/predictions/*/*.pdb"))

# === Step 2: Gather all relaxed pdbs and create fast lookup
relaxed_pdbs = list(TCRGEN_ROOT.glob("**/relaxed/*.pdb"))
relaxed_stems = {p.stem for p in relaxed_pdbs}

# === Step 3: Match each predicted to relaxed
missing = []
dir_counts = defaultdict(int)

for pred_pdb in predicted_pdbs:
    if ".ipynb_checkpoints" in str(pred_pdb):
        continue

    pred_stem = pred_pdb.stem
    relaxed_stem = f"{pred_stem}_relaxed_0001"

    if relaxed_stem not in relaxed_stems:
        missing.append(str(pred_pdb))

        # Grouping by relative path to give per-context info
        try:
            relative_parent = pred_pdb.parent.parent.relative_to(TCRGEN_ROOT)
            dir_counts[str(relative_parent)] += 1
        except Exception:
            pass

# === Step 4: Save missing list
OUTPUT_FILE.parent.mkdir(parents=True, exist_ok=True)
with open(OUTPUT_FILE, "w") as f:
    f.write("\n".join(missing))

# === Final Reporting
if missing:
    print(f"❌ Missing relaxed .pdbs written to: {OUTPUT_FILE}")
    print(f"Total missing: {len(missing)}")
    print("\nBreakdown by prediction group directory:")
    for group_dir, count in sorted(dir_counts.items()):
        print(f"{group_dir}: {count}")
else:
    print("✅ All relaxed .pdbs are present.")

#sbatch relax.sh
# Out:
# ✅ All relaxed .pdbs are present.

# %% [markdown]
# ### RMSD calculations to full structure and cdr3b:epitope interface
# contact determined by findings outlined in this 2016 paper (https://pmc.ncbi.nlm.nih.gov/articles/PMC4894841/)

# %%
# full structure RMSD

import numpy as np
import pandas as pd
from pathlib import Path
from Bio.PDB import PDBParser, PPBuilder
from Bio import pairwise2
from Bio.Align import substitution_matrices
from Bio.SVDSuperimposer import SVDSuperimposer

# === Config ===
solved_dir = Path("/scratch/ggrama/tcrgen/solved/ground_truth_pdbs") # write ground truth pdbs to a dir under solved/ (pull from rcsb)
predicted_dir = Path("/scratch/ggrama/tcrgen/solved/relaxed") # use relaxed structure
output_file = Path("groundtruth_rmsd.csv")

parser = PDBParser(QUIET=True)
ppb = PPBuilder()
matrix = substitution_matrices.load("BLOSUM62")

# === Extract CA coordinates and sequence from first valid chain ===
def get_ca_coords_and_seq(pdb_path):
    structure = parser.get_structure(pdb_path.stem, pdb_path)
    for model in structure:
        for chain in model:
            peptides = ppb.build_peptides(chain)
            if not peptides:
                continue
            seq = str(peptides[0].get_sequence())
            ca_coords = [
                residue["CA"].get_coord()
                for residue in chain
                if "CA" in residue
            ]
            return np.array(ca_coords), seq
    return None, ""

# === Align sequences and get matched CA coordinates ===
def extract_flexible_ca_coords(pred_coords, pred_seq, solved_coords, solved_seq):
    alignment = pairwise2.align.globalds(solved_seq, pred_seq, matrix, -10, -1, one_alignment_only=True)[0]
    aligned_solved = alignment.seqA
    aligned_pred = alignment.seqB

    matched_pred_coords = []
    matched_solved_coords = []

    pred_index = 0
    solved_index = 0

    for a_s, a_p in zip(aligned_solved, aligned_pred):
        if a_s != '-' and a_p != '-':
            matched_pred_coords.append(pred_coords[pred_index])
            matched_solved_coords.append(solved_coords[solved_index])
        if a_s != '-':
            solved_index += 1
        if a_p != '-':
            pred_index += 1

    return np.array(matched_pred_coords), np.array(matched_solved_coords)

# === Main loop ===
results = []
predicted_files = list(predicted_dir.glob("*.pdb"))
print(f"Found {len(predicted_files)} predicted structures")

for pred_path in predicted_files:
    stem = pred_path.stem
    if "_run" not in stem:
        print(f"⚠️ Skipping {stem}: no '_run' in filename")
        continue

    pdb_id = stem.split("_run")[0]
    solved_path = solved_dir / f"{pdb_id}.pdb"

    if not solved_path.exists():
        print(f"❌ Skipping {pdb_id}: no solved file found.")
        continue

    pred_coords, pred_seq = get_ca_coords_and_seq(pred_path)
    solved_coords, solved_seq = get_ca_coords_and_seq(solved_path)

    if pred_coords is None or solved_coords is None:
        print(f"❌ Skipping {pdb_id}: could not extract CA coordinates.")
        continue

    try:
        sub_pred_coords, sub_solved_coords = extract_flexible_ca_coords(
            pred_coords, pred_seq, solved_coords, solved_seq
        )

        if sub_pred_coords.shape != sub_solved_coords.shape or sub_pred_coords.shape[0] < 5:
            print(f"⚠️ Poor alignment for {pdb_id}: {sub_pred_coords.shape} vs {sub_solved_coords.shape}")
            continue

        sup = SVDSuperimposer()
        sup.set(sub_pred_coords, sub_solved_coords)
        sup.run()
        rmsd = sup.get_rms()

        results.append((pdb_id, pred_path.name, solved_path.name, sub_pred_coords.shape[0], rmsd))

    except Exception as e:
        print(f"❌ Error on {pdb_id}: {e}")

# === Save CSV ===
df = pd.DataFrame(results, columns=["pdb_id", "predicted_file", "solved_file", "aligned_residues", "ca_rmsd"])
df.to_csv(output_file, index=False)
print(f"✅ Flexible RMSD complete — saved to {output_file}")
# Out:
# /home/ggrama/.local/lib/python3.12/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(
# Found 6 predicted structures
# ✅ Flexible RMSD complete — saved to groundtruth_rmsd.csv

# %%
df = pd.read_csv("groundtruth_rmsd.csv") #should be well under 2 Angstroms
df
# Out:
#   pdb_id                                     predicted_file solved_file  \
# 0   2vlk  2vlk_run_T00000_A0201_GILGFVFTL_0_model_1_mode...    2vlk.pdb
# 1   5euo  5euo_run_T00000_A0201_GILGFVFTL_0_model_1_mode...    5euo.pdb
# 2   2vlr  2vlr_run_T00000_A0201_GILGFVFTL_0_model_1_mode...    2vlr.pdb
# 3   1oga  1oga_run_T00000_A0201_GILGFVFTL_0_model_1_mode...    1oga.pdb
# 4   2vlj  2vlj_run_T00000_A0201_GILGFVFTL_0_model_1_mode...    2vlj.pdb
# 5   5isz  5isz_run_T00000_A0201_GILGFVFTL_0_model_1_mode...    5isz.pdb
#
#    aligned_residues   ca_rmsd
# 0               175  0.656152
# 1               175  0.629052
# 2               175  0.970827
# 3               175  0.603651
# 4               175  0.737704
# 5               175  0.568861

# %%
# cdr3b:epitope interface RMSD

import pandas as pd
import numpy as np
from pathlib import Path
from Bio.PDB import PDBParser
from Bio.SVDSuperimposer import SVDSuperimposer
from Bio import pairwise2
from Bio.Align import substitution_matrices
from Bio.Data.IUPACData import protein_letters_3to1
import re

# === Config ===
RELAXED_DIR = Path("/scratch/ggrama/tcrgen/solved/relaxed")
SOLVED_DIR = Path("/scratch/ggrama/tcrgen/solved/ground_truth_pdbs")
USER_TARGETS_DIR = Path("/scratch/ggrama/tcrgen/solved/user_outputs") # pulls targets.tsv file to identify cdr3b and epitope sequences for calculations, used for both ground truth and predicted pair (since they are the same sequence)
OUTPUT = Path("/home/ggrama/tcrgen/solved_relaxed_cdr3b_epitope_rmsd.csv")
DIST_CUTOFF = 7.0 

parser = PDBParser(QUIET=True)
matrix = substitution_matrices.load("BLOSUM62")

def extract_pdb_id(filename):
    match = re.match(r"([0-9][a-zA-Z0-9]{3})", filename)
    return match.group(1).lower() if match else None

def load_coords_seq_resnums(pdb_path):
    structure = parser.get_structure(pdb_path.stem, pdb_path)
    for chain in structure.get_chains():
        coords, seq, resnums = [], [], []
        for residue in chain:
            if "CA" in residue:
                coords.append(residue["CA"].get_coord())
                resname = residue.resname.strip().capitalize()
                seq.append(protein_letters_3to1.get(resname, "X"))
                resnums.append(residue.get_id()[1])
        if coords:
            return np.array(coords), "".join(seq), resnums
    return None, None, None

def find_subseq_indices_aligned(seq, subseq):
    aln = pairwise2.align.globalds(subseq, seq, matrix, -10, -1, one_alignment_only=True)
    if not aln:
        return None
    aligned_sub, aligned_seq = aln[0].seqA, aln[0].seqB
    indices, seq_idx = [], 0
    for a_sub, a_seq in zip(aligned_sub, aligned_seq):
        if a_sub != "-" and a_seq != "-":
            indices.append(seq_idx)
        if a_seq != "-":
            seq_idx += 1
    return indices if len(indices) >= 3 else None

def get_contact_indices(coords1, coords2, cutoff=7.0):
    contacts = []
    for i, c1 in enumerate(coords1):
        for c2 in coords2:
            if np.linalg.norm(c1 - c2) <= cutoff:
                contacts.append(i)
                break
    return sorted(set(contacts))

def get_target_sequences(pdb_id):
    tsv = USER_TARGETS_DIR / pdb_id / "targets.tsv"
    if not tsv.exists():
        return None, None
    df = pd.read_csv(tsv, sep="\t")
    colmap = {col.lower(): col for col in df.columns}
    cdr3b_col = next((colmap[k] for k in colmap if "cdr3b" in k), None)
    pep_col = next((colmap[k] for k in colmap if "peptide" in k), None)
    if not cdr3b_col or not pep_col:
        return None, None
    cdr3b, peptide = df.at[0, cdr3b_col], df.at[0, pep_col]
    if pd.isna(cdr3b) or pd.isna(peptide):
        return None, None
    return str(cdr3b).strip(), str(peptide).strip()

# === Main
results = []

relaxed_files = sorted(RELAXED_DIR.glob("*_relaxed_0001.pdb"))
for relaxed_path in relaxed_files:
    pdb_id = extract_pdb_id(relaxed_path.name)
    if not pdb_id:
        continue

    solved_path = SOLVED_DIR / f"{pdb_id}.pdb"
    if not solved_path.exists():
        print(f"[ERROR] No solved structure for {pdb_id}")
        continue

    cdr3b, peptide = get_target_sequences(pdb_id)
    if not cdr3b or not peptide:
        print(f"[WARN] Skipping {pdb_id}: Missing CDR3b or peptide")
        continue

    pred_coords, pred_seq, pred_resnums = load_coords_seq_resnums(relaxed_path)
    solved_coords, solved_seq, solved_resnums = load_coords_seq_resnums(solved_path)

    if pred_coords is None or solved_coords is None:
        print(f"[WARN] {pdb_id}: Could not load coordinate data")
        continue

    idx_cdr3b_pred = find_subseq_indices_aligned(pred_seq, cdr3b)
    idx_pep_pred = find_subseq_indices_aligned(pred_seq, peptide)
    idx_cdr3b_solved = find_subseq_indices_aligned(solved_seq, cdr3b)
    idx_pep_solved = find_subseq_indices_aligned(solved_seq, peptide)

    if not idx_cdr3b_pred or not idx_pep_pred or not idx_cdr3b_solved or not idx_pep_solved:
        print(f"[WARN] Alignment failed for {pdb_id}")
        continue

    contact_solved = get_contact_indices(solved_coords[idx_cdr3b_solved], solved_coords[idx_pep_solved], DIST_CUTOFF)
    contact_residues_solved = set(solved_resnums[idx_cdr3b_solved[i]] for i in contact_solved)

    print(f"[DEBUG] {pdb_id}: solved contact residue numbers: {sorted(contact_residues_solved)}")

    aln = pairwise2.align.globalds(pred_seq, solved_seq, matrix, -10, -1, one_alignment_only=True)[0]
    aligned_pred, aligned_solved = aln.seqA, aln.seqB
    i_pred = i_solved = 0
    matched_pred, matched_solved = [], []

    for a_p, a_s in zip(aligned_pred, aligned_solved):
        if a_p != "-" and a_s != "-":
            r_pred = pred_resnums[i_pred]
            r_solved = solved_resnums[i_solved]
            if r_solved in contact_residues_solved:
                matched_pred.append(pred_coords[i_pred])
                matched_solved.append(solved_coords[i_solved])
        if a_p != "-": i_pred += 1
        if a_s != "-": i_solved += 1

    print(f"[DEBUG] {pdb_id}: matched {len(matched_pred)} residues in interface")

    if len(matched_pred) < 3:
        print(f"[WARN] {pdb_id}: Not enough matched interface residues ({len(matched_pred)})")
        continue

    sup = SVDSuperimposer()
    sup.set(np.array(matched_solved), np.array(matched_pred))
    sup.run()
    rmsd = sup.get_rms()

    results.append({
        "pdb_id": pdb_id,
        "relaxed_file": relaxed_path.name,
        "solved_file": solved_path.name,
        "interface_residues": len(matched_pred),
        "cdr3b_epitope_rmsd": rmsd
    })

    print(f"[OK] {pdb_id}: RMSD = {rmsd:.3f} A")

# Save output
df = pd.DataFrame(results)
df.to_csv(OUTPUT, index=False)
print(f"\n[DONE] Saved {len(results)} RMSDs to {OUTPUT}")
# Out:
# [DEBUG] 1oga: solved contact residue numbers: [1, 2, 3, 4, 5, 6]
# [DEBUG] 1oga: matched 6 residues in interface
# [OK] 1oga: RMSD = 0.250 A
# [DEBUG] 2vlj: solved contact residue numbers: [1, 2, 3, 4, 5, 6]
# [DEBUG] 2vlj: matched 6 residues in interface
# [OK] 2vlj: RMSD = 0.253 A
# [DEBUG] 2vlk: solved contact residue numbers: [1, 2, 3, 4, 5, 6]
# [DEBUG] 2vlk: matched 6 residues in interface
# [OK] 2vlk: RMSD = 0.306 A
# [DEBUG] 2vlr: solved contact residue numbers: [1, 2, 3, 4, 5, 6]
# [DEBUG] 2vlr: matched 6 residues in interface
# [OK] 2vlr: RMSD = 0.348 A
# [DEBUG] 5euo: solved contact residue numbers: [1, 2, 3, 4, 5, 6]
# [DEBUG] 5euo: matched 6 residues in interface
# [OK] 5euo: RMSD = 0.383 A
# [DEBUG] 5isz: solved contact residue numbers: [1, 2, 3, 4, 5]
# [DEBUG] 5isz: matched 5 residues in interface
# [OK] 5isz: RMSD = 0.231 A
#
# [DONE] Saved 6 RMSDs to /home/ggrama/tcrgen/solved_relaxed_cdr3b_epitope_rmsd.csv

# %% [markdown]
# # RMSD of generated sequences to experimental TCRs

# %% [markdown]
# ## structure prediction using TCRDock

# %% [markdown]
# ### Needleman-Wunsch + BLOSUM62 for cdr3b similarity
# align generated cdr3b to ground truth cdr3b sequences to determine most compatible/similar structure for modelling

# %%
import pandas as pd
from pathlib import Path
from Bio.Align import PairwiseAligner, substitution_matrices

# === Setup aligner ===
aligner = PairwiseAligner()
aligner.mode = "global"
aligner.open_gap_score = -7        ## gap and extension penalty used by tcrdist
aligner.extend_gap_score = -1
aligner.substitution_matrix = substitution_matrices.load("BLOSUM62")

# === Load solved metadata ===
solved_metadata_path = Path("/home/ggrama/tcrgen/compiled_solved_metadata.csv")
solved_df = pd.read_csv(solved_metadata_path)

# === Base directory and exclusions ===
base_dir = Path("/scratch/ggrama/tcrgen")
exclude_substrings = ["temper_0.7", ".ipynb_checkpoints", "gen10", "in_sample"]

# === Loop through all relevant CSVs ===
for csv_path in base_dir.rglob("*.csv"):
    if csv_path.name == "needlemen.csv":
        continue  # Skip output files
    if any(excl in str(csv_path) for excl in exclude_substrings):
        continue  # Skip excluded paths

    try:
        gen_df = pd.read_csv(csv_path)
        if "tcr" not in gen_df.columns:
            print(f"Skipping {csv_path} (missing 'tcr' column)")
            continue

        results = []

        for idx, row in gen_df.iterrows():
            gen_seq = row["tcr"]
            if not isinstance(gen_seq, str) or not gen_seq:
                continue

            best_score = float("-inf")
            best_match_id = None
            best_match_seq = None

            for _, solved_row in solved_df.iterrows():
                try:
                    solved_seq = solved_row["CDR3β"]
                    score = aligner.score(gen_seq, solved_seq)
                    if score > best_score:
                        best_score = score
                        best_match_id = solved_row["PDB ID"]
                        best_match_seq = solved_seq
                except Exception as e:
                    print(f"Alignment error with {solved_row['PDB ID']}: {e}")
                    continue

            results.append({
                "Generated_Index": idx,
                "Generated_TCR": gen_seq,
                "Best_Solved_ID": best_match_id,
                "Best_Solved_TCR": best_match_seq,
                "Alignment_Score": best_score
            })

        if results:
            out_df = pd.DataFrame(results)
            output_path = csv_path.parent / "needlemen.csv"
            out_df.to_csv(output_path, index=False)
            print(f"Saved: {output_path}")

    except Exception as e:
        print(f"Error processing {csv_path}: {e}")
# Out:
# ✅ Saved: /scratch/ggrama/tcrgen/gen5/fsp-oracle/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/gen5/scp-select/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/gen5/fsp-healthy/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/gen5/fsp-fake/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/gen5/scp-chain/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/gen5/scp-random/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/gen0/out_sample/temper_0.4/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/controls/prior/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/controls/gptll/needlemen.csv
# ✅ Saved: /scratch/ggrama/tcrgen/controls/random/needlemen.csv

# %% [markdown]
# ### generating input files for tcrdock modelling
# substitutes cdr3b sequence while leaving rest of input the same as most aligned ground truth

# %%
import os
import pandas as pd

# === Constants ===
solved_meta_file = "/home/ggrama/tcrgen/compiled_solved_metadata.csv"
root_dir = "/scratch/ggrama/tcrgen"
organism = 'human'
mhc_class = 1
mhc = 'A*02:01'
required_cols = {'Peptide', 'TRAV', 'TRAJ', 'CDR3α', 'TRBV', 'TRBJ', 'CDR3β'}

# === Load solved metadata once ===
solved_meta = pd.read_csv(solved_meta_file)
solved_meta = solved_meta.set_index("ID")

# === Helper function ===
def get_relative_id(input_path, root_dir="/scratch/ggrama/tcrgen"):
    """
    Returns a relative ID like 'gen5_fsp-oracle' or 'controls_prior' based on input path.
    """
    rel_path = os.path.relpath(input_path, root_dir)
    parts = rel_path.split(os.sep)

    if parts[0] in {"gen5", "gen10"}:
        return f"{parts[0]}_{parts[1]}"
    elif parts[0] == "controls":
        return f"controls_{parts[1]}"
    elif parts[0] == "gen0" and parts[1] in {"in_sample", "out_sample"}:
        return f"{parts[0]}_{parts[1]}_{parts[2]}"
    else:
        raise ValueError(f"Unrecognized path structure for: {input_path}")

# === Main loop ===
for dirpath, _, filenames in os.walk(root_dir):
    if ".ipynb_checkpoints" in dirpath:
        continue

    for fname in filenames:
        if fname == "needlemen.csv":
            input_path = os.path.join(dirpath, fname)

            try:
                base_id = get_relative_id(input_path, root_dir)
                matched = pd.read_csv(input_path)
            except Exception as e:
                print(f"Failed to load {input_path}: {e}")
                continue

            out_dir = os.path.join(dirpath, "user_targets")
            os.makedirs(out_dir, exist_ok=True)

            for i, row in matched.iterrows():
                gen_cdr3b = row.get("Generated_TCR") or row.get("Generated_CDR3b", "")
                solved_id = row["Best_Solved_ID"]

                if solved_id not in solved_meta.index:
                    print(f"Missing solved metadata for {solved_id}")
                    continue

                solved_row = solved_meta.loc[solved_id]

                if any(pd.isna(solved_row[col]) or str(solved_row[col]).strip() == "" for col in required_cols):
                    print(f"Skipping {solved_id} — missing required fields")
                    continue

                target = pd.DataFrame([dict(
                    organism=organism,
                    mhc_class=mhc_class,
                    mhc=mhc,
                    peptide=solved_row['Peptide'],
                    va=solved_row['TRAV'],
                    ja=solved_row['TRAJ'],
                    cdr3a=solved_row['CDR3α'],
                    vb=solved_row['TRBV'],
                    jb=solved_row['TRBJ'],
                    cdr3b=gen_cdr3b
                )])

                outname = f"{base_id}_{i}.tsv"
                outpath = os.path.join(out_dir, outname)

                try:
                    target.to_csv(outpath, sep="\t", index=False)
                    print(f"Wrote: {outpath}")
                except Exception as e:
                    print(f"Failed to write {outpath}: {e}")
# Out:
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_0.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_1.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_2.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_3.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_4.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_5.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_6.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_7.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_8.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_9.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_10.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_11.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_12.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_13.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_14.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_15.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_16.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_17.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_18.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_19.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_20.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_21.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_22.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_23.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_24.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_25.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_26.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_27.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_28.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_29.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_30.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_31.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_32.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_33.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_34.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_35.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_36.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_37.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_38.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_39.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_40.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_41.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_42.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_43.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_44.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_45.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_46.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_47.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_48.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_49.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_50.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_51.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_52.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_53.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_54.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_55.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_56.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_57.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_58.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_59.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_60.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_61.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_62.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_63.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_64.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_65.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_66.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_67.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_68.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_69.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_70.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_71.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_72.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_73.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_74.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_75.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_76.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_77.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_78.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_79.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_80.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_81.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_82.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_83.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_84.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_85.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_86.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_87.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_88.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_89.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_90.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_91.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_92.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_93.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_94.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_95.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_96.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_97.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_98.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_99.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_100.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_101.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_102.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_103.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_104.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_105.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_106.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_107.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_108.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_109.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_110.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_111.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_112.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_113.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_114.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_115.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_116.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_117.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_118.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_119.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_120.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_121.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_122.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_123.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_124.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_125.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_126.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_127.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_128.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_129.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_130.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_131.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_132.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_133.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_134.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_135.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_136.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_137.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_138.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_139.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_140.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_141.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_142.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_143.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_144.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_145.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_146.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_147.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_148.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_149.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_150.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_151.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_152.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_153.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_154.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_155.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_156.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_157.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_158.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_159.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_160.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_161.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_162.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_163.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_164.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_165.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_166.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_167.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_168.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_169.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_170.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_171.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_172.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_173.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_174.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_175.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_176.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_177.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_178.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_179.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_180.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_181.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_182.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_183.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_184.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_185.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_186.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_187.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_188.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_189.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_190.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_191.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_192.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_193.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_194.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_195.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_196.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_197.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_198.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_199.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_200.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_201.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_202.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_203.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_204.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_205.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_206.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_207.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_208.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_209.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_210.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_211.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_212.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_213.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_214.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_215.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_216.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_217.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_218.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_219.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_220.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_221.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_222.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_223.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_224.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_225.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_226.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_227.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_228.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_229.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_230.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_231.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_232.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_233.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_234.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_235.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_236.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_237.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_238.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_239.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_240.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_241.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_242.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_243.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_244.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_245.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_246.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_247.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_248.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_249.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_250.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_251.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_252.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_253.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_254.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_255.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_256.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_257.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_258.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_259.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_260.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_261.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_262.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_263.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_264.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_265.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_266.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_267.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_268.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_269.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_270.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_271.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_272.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_273.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_274.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_275.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_276.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_277.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_278.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_279.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_280.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_281.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_282.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_283.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_284.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_285.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_286.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_287.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_288.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_289.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_290.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_291.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_292.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_293.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_294.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_295.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_296.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_297.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_298.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/fsp-oracle/user_targets/gen5_fsp-oracle_299.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_0.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_1.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_2.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_3.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_4.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_5.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_6.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_7.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_8.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_9.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_10.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_11.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_12.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_13.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_14.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_15.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_16.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_17.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_18.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_19.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_20.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_21.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_22.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_23.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_24.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_25.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_26.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_27.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_28.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_29.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_30.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_31.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_32.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_33.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_34.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_35.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_36.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_37.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_38.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_39.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_40.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_41.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_42.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_43.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_44.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_45.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_46.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_47.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_48.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_49.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_50.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_51.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_52.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_53.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_54.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_55.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_56.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_57.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_58.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_59.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_60.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_61.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_62.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_63.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_64.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_65.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_66.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_67.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_68.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_69.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_70.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_71.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_72.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_73.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_74.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_75.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_76.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_77.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_78.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_79.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_80.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_81.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_82.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_83.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_84.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_85.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_86.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_87.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_88.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_89.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_90.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_91.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_92.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_93.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_94.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_95.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_96.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_97.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_98.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_99.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_100.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_101.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_102.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_103.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_104.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_105.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_106.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_107.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_108.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_109.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_110.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_111.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_112.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_113.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_114.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_115.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_116.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_117.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_118.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_119.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_120.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_121.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_122.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_123.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_124.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_125.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_126.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_127.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_128.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_129.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_130.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_131.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_132.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_133.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_134.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_135.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_136.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_137.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_138.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_139.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_140.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_141.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_142.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_143.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_144.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_145.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_146.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_147.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_148.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_149.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_150.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_151.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_152.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_153.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_154.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_155.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_156.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_157.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_158.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_159.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_160.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_161.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_162.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_163.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_164.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_165.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_166.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_167.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_168.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_169.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_170.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_171.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_172.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_173.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_174.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_175.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_176.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_177.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_178.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_179.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_180.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_181.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_182.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_183.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_184.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_185.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_186.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_187.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_188.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_189.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_190.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_191.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_192.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_193.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_194.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_195.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_196.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_197.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_198.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_199.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_200.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_201.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_202.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_203.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_204.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_205.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_206.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_207.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_208.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_209.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_210.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_211.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_212.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_213.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_214.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_215.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_216.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_217.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_218.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_219.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_220.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_221.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_222.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_223.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_224.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_225.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_226.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_227.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_228.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_229.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_230.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_231.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_232.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_233.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_234.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_235.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_236.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_237.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_238.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_239.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_240.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_241.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_242.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_243.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_244.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_245.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_246.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_247.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_248.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_249.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_250.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_251.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_252.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_253.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_254.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_255.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_256.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_257.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_258.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_259.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_260.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_261.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_262.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_263.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_264.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_265.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_266.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_267.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_268.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_269.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_270.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_271.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_272.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_273.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_274.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_275.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_276.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_277.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_278.tsv
# Wrote: /scratch/ggrama/tcrgen/gen5/scp-select/user_targets/gen5_scp-select_279.tsv
# ...
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_108.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_109.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_110.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_111.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_112.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_113.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_114.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_115.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_116.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_117.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_118.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_119.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_120.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_121.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_122.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_123.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_124.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_125.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_126.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_127.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_128.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_129.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_130.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_131.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_132.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_133.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_134.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_135.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_136.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_137.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_138.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_139.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_140.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_141.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_142.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_143.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_144.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_145.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_146.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_147.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_148.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_149.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_150.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_151.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_152.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_153.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_154.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_155.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_156.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_157.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_158.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_159.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_160.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_161.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_162.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_163.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_164.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_165.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_166.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_167.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_168.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_169.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_170.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_171.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_172.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_173.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_174.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_175.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_176.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_177.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_178.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_179.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_180.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_181.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_182.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_183.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_184.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_185.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_186.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_187.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_188.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_189.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_190.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_191.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_192.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_193.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_194.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_195.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_196.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_197.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_198.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_199.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_200.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_201.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_202.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_203.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_204.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_205.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_206.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_207.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_208.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_209.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_210.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_211.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_212.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_213.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_214.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_215.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_216.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_217.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_218.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_219.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_220.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_221.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_222.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_223.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_224.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_225.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_226.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_227.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_228.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_229.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_230.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_231.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_232.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_233.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_234.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_235.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_236.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_237.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_238.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_239.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_240.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_241.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_242.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_243.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_244.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_245.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_246.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_247.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_248.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_249.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_250.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_251.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_252.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_253.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_254.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_255.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_256.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_257.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_258.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_259.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_260.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_261.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_262.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_263.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_264.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_265.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_266.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_267.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_268.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_269.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_270.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_271.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_272.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_273.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_274.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_275.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_276.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_277.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_278.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_279.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_280.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_281.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_282.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_283.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_284.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_285.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_286.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_287.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_288.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_289.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_290.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_291.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_292.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_293.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_294.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_295.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_296.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_297.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_298.tsv
# Wrote: /scratch/ggrama/tcrgen/controls/random/user_targets/controls_random_299.tsv

# %% [markdown]
# ### inputs for setup.sh
# writes paths to .txt, setup.sh found in scripts/ make sure to change array count

# %%
from pathlib import Path

# === Config ===
ROOT_DIR = Path("/scratch/ggrama/tcrgen")
OUTPUT_FILE = Path("/home/ggrama/tcrgen/scripts/tsv_paths.txt")

# === Remove old output file if it exists
OUTPUT_FILE.unlink(missing_ok=True)

# === Search for all .tsv files under user_targets/
tsv_files = list(ROOT_DIR.rglob("*/user_targets/*.tsv"))
missing = []

for tsv_path in tsv_files:
    if ".ipynb_checkpoints" in str(tsv_path):
        continue

    basename = tsv_path.stem
    parent_dir = tsv_path.parent
    expected_targets_tsv = parent_dir.parent / "user_outputs" / basename / "targets.tsv"

    if not expected_targets_tsv.exists():
        missing.append(str(tsv_path))

# === Write missing paths to file
if missing:
    OUTPUT_FILE.parent.mkdir(parents=True, exist_ok=True)
    with open(OUTPUT_FILE, "w") as f:
        f.write("\n".join(missing))
    print(f"❌ Missing targets.tsv files listed in: {OUTPUT_FILE}")
    print(f"Count: {len(missing)}")
else:
    print("✅ All user_outputs/…/targets.tsv files present.")
# Out:
# ✅ All user_outputs/…/targets.tsv files present.

# %% [markdown]
# ### inputs for predict.sh
# writes paths to .txt, ensure alphafold env is set up prior to running, check array count

# %%
from pathlib import Path

# === Config ===
ROOT_DIR = Path("/scratch/ggrama/tcrgen")
OUTPUT_FILE = Path("/home/ggrama/tcrgen/scripts/targets_paths.txt")

# === Remove old file if it exists ===
OUTPUT_FILE.unlink(missing_ok=True)

# === Locate all targets.tsv files ===
targets_files = list(ROOT_DIR.rglob("targets.tsv"))
missing = []

for targets_path in targets_files:
    if ".ipynb_checkpoints" in str(targets_path):
        continue

    user_outputs_dir = targets_path.parent
    target_name = user_outputs_dir.name.strip()
    base_dir = user_outputs_dir.parent.parent
    predictions_dir = base_dir / "predictions" / target_name

    if not any(predictions_dir.glob("*.pdb")):
        missing.append(targets_path)

# === Save missing targets.tsv paths ===
if missing:
    OUTPUT_FILE.parent.mkdir(parents=True, exist_ok=True)
    with open(OUTPUT_FILE, "w") as f:
        for path in missing:
            f.write(str(path) + "\n")
    print(f"Missing .pdb count: {len(missing)}")
else:
    print("All prediction outputs present.")
# Out:
# All prediction outputs present.

# %% [markdown]
# ### inputs for relax.sh
# rinse and repeat, check array count

# %%
from pathlib import Path
from collections import defaultdict

# === Constants ===
TCRGEN_ROOT = Path("/scratch/ggrama/tcrgen")
OUTPUT_FILE = Path("/home/ggrama/tcrgen/scripts/pdb_paths.txt")

# === Step 1: Gather all predicted pdbs
predicted_pdbs = list(TCRGEN_ROOT.glob("**/predictions/*/*.pdb"))

# === Step 2: Gather all relaxed pdbs and create fast lookup
relaxed_pdbs = list(TCRGEN_ROOT.glob("**/relaxed/*.pdb"))
relaxed_stems = {p.stem for p in relaxed_pdbs}

# === Step 3: Match each predicted to relaxed
missing = []
dir_counts = defaultdict(int)

for pred_pdb in predicted_pdbs:
    if ".ipynb_checkpoints" in str(pred_pdb):
        continue

    pred_stem = pred_pdb.stem
    relaxed_stem = f"{pred_stem}_relaxed_0001"

    if relaxed_stem not in relaxed_stems:
        missing.append(str(pred_pdb))

        # Grouping by relative path to give per-context info
        try:
            relative_parent = pred_pdb.parent.parent.relative_to(TCRGEN_ROOT)
            dir_counts[str(relative_parent)] += 1
        except Exception:
            pass

# === Step 4: Save missing list
OUTPUT_FILE.parent.mkdir(parents=True, exist_ok=True)
with open(OUTPUT_FILE, "w") as f:
    f.write("\n".join(missing))

# === Final Reporting
if missing:
    print(f"❌ Missing relaxed .pdbs written to: {OUTPUT_FILE}")
    print(f"Total missing: {len(missing)}")
    print("\nBreakdown by prediction group directory:")
    for group_dir, count in sorted(dir_counts.items()):
        print(f"{group_dir}: {count}")
else:
    print("✅ All relaxed .pdbs are present.")
# Out:
# ✅ All relaxed .pdbs are present.

# %% [markdown]
# ## RMSD Calculation
# use relaxed structures, cdr3b and epitope indicies are determined from .../user_outputs/{gen_idx}/targets.tsv

# %%
# will only update .csv, if precomputed rmsds are inaccurate, make sure to remove those entries otherwise calculations will not be updated

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from Bio.PDB import PDBParser
from Bio.SVDSuperimposer import SVDSuperimposer
from Bio.Align import PairwiseAligner
from Bio.Align.substitution_matrices import load
import os

# === Constants ===
SCRATCH_ROOT = Path("/scratch/ggrama/tcrgen")
GROUPED_ROOT = SCRATCH_ROOT / "solved/relaxed"
OUTPUT_CSV = Path("/home/ggrama/tcrgen/cdr3b_epitope_rmsd_flexible.csv")

# === Setup Parsers ===
parser = PDBParser(QUIET=True)
aligner = PairwiseAligner()
aligner.substitution_matrix = load("BLOSUM62")
aligner.open_gap_score = -7
aligner.extend_gap_score = -1
aligner.mode = "global"

# === Solved PDB Map ===
solved_pdbs = {
    p.name.split("_run")[0].lower(): p
    for p in GROUPED_ROOT.glob("*.pdb")
}

# === Helper: resolve CDR3β from targets.tsv ===
def get_cdr3b(tsv_path):
    if not tsv_path.exists():
        print(f"❌ Missing {tsv_path}")
        return None
    try:
        df = pd.read_csv(tsv_path, sep="\t")
        for col in df.columns:
            if "cdr3b" in col.lower():
                return str(df.loc[0, col])
        print(f"❌ No recognizable cdr3b column in {tsv_path.name}")
        return None
    except Exception as e:
        print(f"⚠️ Failed to read {tsv_path}: {e}")
        return None

# === Helper: get relative group identifier ===
def get_relative_id(input_path, root_dir="/scratch/ggrama/tcrgen"):
    rel_path = os.path.relpath(str(input_path), root_dir)
    parts = rel_path.split(os.sep)
    try:
        if parts[0] in {"gen5", "gen10"} and len(parts) > 1:
            return f"{parts[0]}_{parts[1]}"
        elif parts[0] == "controls" and len(parts) > 1:
            return f"controls_{parts[1]}"
        elif parts[0] == "gen0" and parts[1] in {"in_sample", "out_sample"} and len(parts) > 2:
            return f"{parts[0]}_{parts[1]}_{parts[2]}"
        else:
            return "unknown"
    except IndexError:
        return "unknown"

# === Load match CSVs ===
match_csvs = sorted([
    p for p in SCRATCH_ROOT.rglob("needlemen.csv")
    if ".ipynb_checkpoints" not in str(p)
])

# === Load existing RMSDs (if available) ===
if OUTPUT_CSV.exists():
    existing_df = pd.read_csv(OUTPUT_CSV)
    existing_set = set(existing_df["predicted_pdb"].tolist())
    print(f"🔁 Loaded {len(existing_set)} previously computed RMSDs")
else:
    existing_df = pd.DataFrame()
    existing_set = set()

results = []

for match_csv in match_csvs:
    match_dir = match_csv.parent
    group_id = get_relative_id(match_dir)

    try:
        df = pd.read_csv(match_csv)
    except Exception as e:
        print(f"❌ Failed to read {match_csv.name}: {e}")
        continue

    for _, row in df.iterrows():
        try:
            gen_idx = int(row["Generated_Index"])
        except Exception as e:
            print(f"❌ Invalid index: {row} — {e}")
            continue

        # === Resolve gen_id and paths ===
        relaxed_files = list((match_dir / "relaxed").glob(f"*_{gen_idx}_run*_relaxed_0001.pdb"))
        if not relaxed_files:
            print(f"❌ No relaxed PDB for index {gen_idx} in {match_dir}/relaxed")
            continue

        # e.g. controls_random_0_run_... → controls_random_0
        gen_id = relaxed_files[0].name.split("_run")[0]
        gen_folder = match_dir / "user_outputs" / gen_id
        tsv_path = gen_folder / "targets.tsv"

        if not tsv_path.exists():
            print(f"❌ Missing targets.tsv at {tsv_path}")
            continue

        print(f"✅ Index {gen_idx} → gen_id '{gen_id}' → {tsv_path}")

        pred_seq = get_cdr3b(tsv_path)
        solved_id = str(row["Best_Solved_ID"]).lower().strip()
        solved_tsv = SCRATCH_ROOT / "solved/user_outputs" / f"{solved_id}" / "targets.tsv"
        solved_seq = get_cdr3b(solved_tsv)

        if not pred_seq or not solved_seq:
            continue

        pred_relaxed_pdb = relaxed_files[0]
        solved_pdb = solved_pdbs.get(solved_id)
        if not solved_pdb or not solved_pdb.exists():
            print(f"❌ Missing solved structure for {solved_id}")
            continue

        # === Sequence alignment
        try:
            alignment = aligner.align(pred_seq, solved_seq)[0]
            pred_idx, solved_idx = [], []
            for (i1, i2), (j1, j2) in zip(*alignment.aligned):
                pred_idx.extend(range(i1, i2))
                solved_idx.extend(range(j1, j2))

            if len(pred_idx) != len(solved_idx):
                print(f"⚠️ Alignment mismatch: {gen_id}")
                continue

            pred_atoms = [a for a in list(parser.get_structure(gen_id, pred_relaxed_pdb).get_chains())[0].get_atoms() if a.get_id() == 'CA']
            solved_atoms = [a for a in list(parser.get_structure(solved_id, solved_pdb).get_chains())[0].get_atoms() if a.get_id() == 'CA']
            pred_coords = [pred_atoms[i].get_coord() for i in pred_idx if i < len(pred_atoms)]
            solved_coords = [solved_atoms[i].get_coord() for i in solved_idx if i < len(solved_atoms)]

            if len(pred_coords) != len(solved_coords) or not pred_coords:
                print(f"⚠️ Empty or mismatched coordinates for {gen_id}")
                continue

            sup = SVDSuperimposer()
            sup.set(np.array(solved_coords), np.array(pred_coords))
            sup.run()
            rmsd = sup.get_rms()

            if pred_relaxed_pdb.name in existing_set:
                print(f"⏭️ Skipping {pred_relaxed_pdb.name} — already computed")
                continue
            
            results.append({
                "predicted_pdb": pred_relaxed_pdb.name,
                "solved_id": solved_id,
                "group_dir": group_id,
                "rmsd_flexible": rmsd
            })

            print(f"✅ {gen_id} → RMSD: {rmsd:.3f} Å")

        except Exception as e:
            print(f"❌ Failed on {gen_id}: {e}")

# === Save results
if results:
    df_out = pd.DataFrame(results)
    df_out.to_csv(OUTPUT_CSV, index=False)
    print(f"\n🎉 Done. Saved {len(results)} RMSDs to: {OUTPUT_CSV}")
else:
    print("⚠️ No RMSDs computed.")
# Out:
# 🔁 Loaded 300 previously computed RMSDs
# ✅ Index 0 → gen_id 'controls_gptll_0' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_0/targets.tsv
# ⏭️ Skipping controls_gptll_0_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 1 → gen_id 'controls_gptll_1' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_1/targets.tsv
# ⏭️ Skipping controls_gptll_1_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 2 → gen_id 'controls_gptll_2' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_2/targets.tsv
# ⏭️ Skipping controls_gptll_2_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 3 → gen_id 'controls_gptll_3' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_3/targets.tsv
# ⏭️ Skipping controls_gptll_3_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 4 → gen_id 'controls_gptll_4' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_4/targets.tsv
# ⏭️ Skipping controls_gptll_4_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 5 → gen_id 'controls_gptll_5' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_5/targets.tsv
# ⏭️ Skipping controls_gptll_5_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 6 → gen_id 'controls_gptll_6' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_6/targets.tsv
# ⏭️ Skipping controls_gptll_6_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 7 → gen_id 'controls_gptll_7' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_7/targets.tsv
# ⏭️ Skipping controls_gptll_7_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 8 → gen_id 'controls_gptll_8' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_8/targets.tsv
# ⏭️ Skipping controls_gptll_8_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 9 → gen_id 'controls_gptll_9' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_9/targets.tsv
# ⏭️ Skipping controls_gptll_9_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 10 → gen_id 'controls_gptll_10' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_10/targets.tsv
# ⏭️ Skipping controls_gptll_10_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 11 → gen_id 'controls_gptll_11' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_11/targets.tsv
# ⏭️ Skipping controls_gptll_11_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 12 → gen_id 'controls_gptll_12' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_12/targets.tsv
# ⏭️ Skipping controls_gptll_12_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 13 → gen_id 'controls_gptll_13' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_13/targets.tsv
# ⏭️ Skipping controls_gptll_13_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 14 → gen_id 'controls_gptll_14' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_14/targets.tsv
# ⏭️ Skipping controls_gptll_14_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 15 → gen_id 'controls_gptll_15' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_15/targets.tsv
# ⏭️ Skipping controls_gptll_15_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 16 → gen_id 'controls_gptll_16' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_16/targets.tsv
# ⏭️ Skipping controls_gptll_16_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 17 → gen_id 'controls_gptll_17' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_17/targets.tsv
# ⏭️ Skipping controls_gptll_17_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 18 → gen_id 'controls_gptll_18' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_18/targets.tsv
# ⏭️ Skipping controls_gptll_18_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 19 → gen_id 'controls_gptll_19' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_19/targets.tsv
# ⏭️ Skipping controls_gptll_19_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 20 → gen_id 'controls_gptll_20' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_20/targets.tsv
# ⏭️ Skipping controls_gptll_20_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 21 → gen_id 'controls_gptll_21' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_21/targets.tsv
# ⏭️ Skipping controls_gptll_21_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 22 → gen_id 'controls_gptll_22' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_22/targets.tsv
# ⏭️ Skipping controls_gptll_22_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 23 → gen_id 'controls_gptll_23' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_23/targets.tsv
# ⏭️ Skipping controls_gptll_23_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 24 → gen_id 'controls_gptll_24' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_24/targets.tsv
# ⏭️ Skipping controls_gptll_24_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 25 → gen_id 'controls_gptll_25' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_25/targets.tsv
# ⏭️ Skipping controls_gptll_25_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 26 → gen_id 'controls_gptll_26' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_26/targets.tsv
# ⏭️ Skipping controls_gptll_26_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 27 → gen_id 'controls_gptll_27' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_27/targets.tsv
# ⏭️ Skipping controls_gptll_27_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 28 → gen_id 'controls_gptll_28' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_28/targets.tsv
# ⏭️ Skipping controls_gptll_28_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 29 → gen_id 'controls_gptll_29' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_29/targets.tsv
# ⏭️ Skipping controls_gptll_29_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 30 → gen_id 'controls_gptll_30' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_30/targets.tsv
# ⏭️ Skipping controls_gptll_30_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 31 → gen_id 'controls_gptll_31' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_31/targets.tsv
# ⏭️ Skipping controls_gptll_31_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 32 → gen_id 'controls_gptll_32' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_32/targets.tsv
# ⏭️ Skipping controls_gptll_32_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 33 → gen_id 'controls_gptll_33' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_33/targets.tsv
# ⏭️ Skipping controls_gptll_33_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 34 → gen_id 'controls_gptll_34' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_34/targets.tsv
# ⏭️ Skipping controls_gptll_34_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 35 → gen_id 'controls_gptll_35' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_35/targets.tsv
# ⏭️ Skipping controls_gptll_35_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 36 → gen_id 'controls_gptll_36' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_36/targets.tsv
# ⏭️ Skipping controls_gptll_36_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 37 → gen_id 'controls_gptll_37' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_37/targets.tsv
# ⏭️ Skipping controls_gptll_37_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 38 → gen_id 'controls_gptll_38' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_38/targets.tsv
# ⏭️ Skipping controls_gptll_38_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 39 → gen_id 'controls_gptll_39' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_39/targets.tsv
# ⏭️ Skipping controls_gptll_39_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 40 → gen_id 'controls_gptll_40' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_40/targets.tsv
# ⏭️ Skipping controls_gptll_40_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 41 → gen_id 'controls_gptll_41' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_41/targets.tsv
# ⏭️ Skipping controls_gptll_41_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 42 → gen_id 'controls_gptll_42' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_42/targets.tsv
# ⏭️ Skipping controls_gptll_42_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 43 → gen_id 'controls_gptll_43' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_43/targets.tsv
# ⏭️ Skipping controls_gptll_43_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 44 → gen_id 'controls_gptll_44' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_44/targets.tsv
# ⏭️ Skipping controls_gptll_44_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 45 → gen_id 'controls_gptll_45' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_45/targets.tsv
# ⏭️ Skipping controls_gptll_45_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 46 → gen_id 'controls_gptll_46' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_46/targets.tsv
# ⏭️ Skipping controls_gptll_46_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 47 → gen_id 'controls_gptll_47' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_47/targets.tsv
# ⏭️ Skipping controls_gptll_47_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 48 → gen_id 'controls_gptll_48' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_48/targets.tsv
# ⏭️ Skipping controls_gptll_48_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 49 → gen_id 'controls_gptll_49' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_49/targets.tsv
# ⏭️ Skipping controls_gptll_49_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 50 → gen_id 'controls_gptll_50' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_50/targets.tsv
# ⏭️ Skipping controls_gptll_50_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 51 → gen_id 'controls_gptll_51' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_51/targets.tsv
# ⏭️ Skipping controls_gptll_51_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 52 → gen_id 'controls_gptll_52' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_52/targets.tsv
# ⏭️ Skipping controls_gptll_52_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 53 → gen_id 'controls_gptll_53' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_53/targets.tsv
# ⏭️ Skipping controls_gptll_53_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 54 → gen_id 'controls_gptll_54' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_54/targets.tsv
# ⏭️ Skipping controls_gptll_54_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 55 → gen_id 'controls_gptll_55' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_55/targets.tsv
# ⏭️ Skipping controls_gptll_55_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 56 → gen_id 'controls_gptll_56' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_56/targets.tsv
# ⏭️ Skipping controls_gptll_56_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 57 → gen_id 'controls_gptll_57' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_57/targets.tsv
# ⏭️ Skipping controls_gptll_57_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 58 → gen_id 'controls_gptll_58' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_58/targets.tsv
# ⏭️ Skipping controls_gptll_58_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 59 → gen_id 'controls_gptll_59' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_59/targets.tsv
# ⏭️ Skipping controls_gptll_59_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 60 → gen_id 'controls_gptll_60' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_60/targets.tsv
# ⏭️ Skipping controls_gptll_60_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 61 → gen_id 'controls_gptll_61' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_61/targets.tsv
# ⏭️ Skipping controls_gptll_61_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 62 → gen_id 'controls_gptll_62' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_62/targets.tsv
# ⏭️ Skipping controls_gptll_62_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 63 → gen_id 'controls_gptll_63' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_63/targets.tsv
# ⏭️ Skipping controls_gptll_63_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 64 → gen_id 'controls_gptll_64' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_64/targets.tsv
# ⏭️ Skipping controls_gptll_64_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 65 → gen_id 'controls_gptll_65' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_65/targets.tsv
# ⏭️ Skipping controls_gptll_65_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 66 → gen_id 'controls_gptll_66' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_66/targets.tsv
# ⏭️ Skipping controls_gptll_66_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 67 → gen_id 'controls_gptll_67' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_67/targets.tsv
# ⏭️ Skipping controls_gptll_67_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 68 → gen_id 'controls_gptll_68' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_68/targets.tsv
# ⏭️ Skipping controls_gptll_68_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 69 → gen_id 'controls_gptll_69' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_69/targets.tsv
# ⏭️ Skipping controls_gptll_69_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 70 → gen_id 'controls_gptll_70' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_70/targets.tsv
# ⏭️ Skipping controls_gptll_70_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 71 → gen_id 'controls_gptll_71' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_71/targets.tsv
# ⏭️ Skipping controls_gptll_71_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 72 → gen_id 'controls_gptll_72' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_72/targets.tsv
# ⏭️ Skipping controls_gptll_72_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 73 → gen_id 'controls_gptll_73' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_73/targets.tsv
# ⏭️ Skipping controls_gptll_73_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 74 → gen_id 'controls_gptll_74' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_74/targets.tsv
# ⏭️ Skipping controls_gptll_74_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 75 → gen_id 'controls_gptll_75' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_75/targets.tsv
# ⏭️ Skipping controls_gptll_75_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 76 → gen_id 'controls_gptll_76' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_76/targets.tsv
# ⏭️ Skipping controls_gptll_76_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 77 → gen_id 'controls_gptll_77' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_77/targets.tsv
# ⏭️ Skipping controls_gptll_77_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 78 → gen_id 'controls_gptll_78' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_78/targets.tsv
# ⏭️ Skipping controls_gptll_78_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 79 → gen_id 'controls_gptll_79' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_79/targets.tsv
# ⏭️ Skipping controls_gptll_79_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 80 → gen_id 'controls_gptll_80' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_80/targets.tsv
# ⏭️ Skipping controls_gptll_80_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 81 → gen_id 'controls_gptll_81' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_81/targets.tsv
# ⏭️ Skipping controls_gptll_81_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 82 → gen_id 'controls_gptll_82' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_82/targets.tsv
# ⏭️ Skipping controls_gptll_82_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 83 → gen_id 'controls_gptll_83' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_83/targets.tsv
# ⏭️ Skipping controls_gptll_83_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 84 → gen_id 'controls_gptll_84' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_84/targets.tsv
# ⏭️ Skipping controls_gptll_84_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 85 → gen_id 'controls_gptll_85' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_85/targets.tsv
# ⏭️ Skipping controls_gptll_85_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 86 → gen_id 'controls_gptll_86' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_86/targets.tsv
# ⏭️ Skipping controls_gptll_86_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 87 → gen_id 'controls_gptll_87' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_87/targets.tsv
# ⏭️ Skipping controls_gptll_87_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 88 → gen_id 'controls_gptll_88' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_88/targets.tsv
# ⏭️ Skipping controls_gptll_88_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 89 → gen_id 'controls_gptll_89' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_89/targets.tsv
# ⏭️ Skipping controls_gptll_89_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 90 → gen_id 'controls_gptll_90' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_90/targets.tsv
# ⏭️ Skipping controls_gptll_90_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 91 → gen_id 'controls_gptll_91' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_91/targets.tsv
# ⏭️ Skipping controls_gptll_91_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 92 → gen_id 'controls_gptll_92' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_92/targets.tsv
# ⏭️ Skipping controls_gptll_92_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 93 → gen_id 'controls_gptll_93' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_93/targets.tsv
# ⏭️ Skipping controls_gptll_93_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 94 → gen_id 'controls_gptll_94' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_94/targets.tsv
# ⏭️ Skipping controls_gptll_94_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 95 → gen_id 'controls_gptll_95' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_95/targets.tsv
# ⏭️ Skipping controls_gptll_95_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 96 → gen_id 'controls_gptll_96' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_96/targets.tsv
# ⏭️ Skipping controls_gptll_96_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 97 → gen_id 'controls_gptll_97' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_97/targets.tsv
# ⏭️ Skipping controls_gptll_97_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 98 → gen_id 'controls_gptll_98' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_98/targets.tsv
# ⏭️ Skipping controls_gptll_98_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 99 → gen_id 'controls_gptll_99' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_99/targets.tsv
# ⏭️ Skipping controls_gptll_99_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 100 → gen_id 'controls_gptll_100' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_100/targets.tsv
# ⏭️ Skipping controls_gptll_100_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 101 → gen_id 'controls_gptll_101' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_101/targets.tsv
# ⏭️ Skipping controls_gptll_101_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 102 → gen_id 'controls_gptll_102' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_102/targets.tsv
# ⏭️ Skipping controls_gptll_102_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 103 → gen_id 'controls_gptll_103' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_103/targets.tsv
# ⏭️ Skipping controls_gptll_103_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 104 → gen_id 'controls_gptll_104' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_104/targets.tsv
# ⏭️ Skipping controls_gptll_104_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 105 → gen_id 'controls_gptll_105' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_105/targets.tsv
# ⏭️ Skipping controls_gptll_105_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 106 → gen_id 'controls_gptll_106' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_106/targets.tsv
# ⏭️ Skipping controls_gptll_106_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 107 → gen_id 'controls_gptll_107' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_107/targets.tsv
# ⏭️ Skipping controls_gptll_107_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 108 → gen_id 'controls_gptll_108' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_108/targets.tsv
# ⏭️ Skipping controls_gptll_108_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 109 → gen_id 'controls_gptll_109' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_109/targets.tsv
# ⏭️ Skipping controls_gptll_109_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 110 → gen_id 'controls_gptll_110' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_110/targets.tsv
# ⏭️ Skipping controls_gptll_110_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 111 → gen_id 'controls_gptll_111' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_111/targets.tsv
# ⏭️ Skipping controls_gptll_111_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 112 → gen_id 'controls_gptll_112' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_112/targets.tsv
# ⏭️ Skipping controls_gptll_112_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 113 → gen_id 'controls_gptll_113' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_113/targets.tsv
# ⏭️ Skipping controls_gptll_113_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 114 → gen_id 'controls_gptll_114' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_114/targets.tsv
# ⏭️ Skipping controls_gptll_114_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 115 → gen_id 'controls_gptll_115' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_115/targets.tsv
# ⏭️ Skipping controls_gptll_115_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 116 → gen_id 'controls_gptll_116' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_116/targets.tsv
# ⏭️ Skipping controls_gptll_116_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 117 → gen_id 'controls_gptll_117' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_117/targets.tsv
# ⏭️ Skipping controls_gptll_117_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 118 → gen_id 'controls_gptll_118' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_118/targets.tsv
# ⏭️ Skipping controls_gptll_118_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 119 → gen_id 'controls_gptll_119' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_119/targets.tsv
# ⏭️ Skipping controls_gptll_119_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 120 → gen_id 'controls_gptll_120' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_120/targets.tsv
# ⏭️ Skipping controls_gptll_120_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 121 → gen_id 'controls_gptll_121' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_121/targets.tsv
# ⏭️ Skipping controls_gptll_121_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 122 → gen_id 'controls_gptll_122' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_122/targets.tsv
# ⏭️ Skipping controls_gptll_122_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 123 → gen_id 'controls_gptll_123' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_123/targets.tsv
# ⏭️ Skipping controls_gptll_123_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 124 → gen_id 'controls_gptll_124' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_124/targets.tsv
# ⏭️ Skipping controls_gptll_124_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 125 → gen_id 'controls_gptll_125' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_125/targets.tsv
# ⏭️ Skipping controls_gptll_125_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 126 → gen_id 'controls_gptll_126' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_126/targets.tsv
# ⏭️ Skipping controls_gptll_126_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 127 → gen_id 'controls_gptll_127' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_127/targets.tsv
# ⏭️ Skipping controls_gptll_127_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 128 → gen_id 'controls_gptll_128' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_128/targets.tsv
# ⏭️ Skipping controls_gptll_128_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 129 → gen_id 'controls_gptll_129' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_129/targets.tsv
# ⏭️ Skipping controls_gptll_129_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 130 → gen_id 'controls_gptll_130' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_130/targets.tsv
# ⏭️ Skipping controls_gptll_130_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 131 → gen_id 'controls_gptll_131' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_131/targets.tsv
# ⏭️ Skipping controls_gptll_131_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 132 → gen_id 'controls_gptll_132' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_132/targets.tsv
# ⏭️ Skipping controls_gptll_132_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 133 → gen_id 'controls_gptll_133' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_133/targets.tsv
# ⏭️ Skipping controls_gptll_133_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 134 → gen_id 'controls_gptll_134' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_134/targets.tsv
# ⏭️ Skipping controls_gptll_134_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 135 → gen_id 'controls_gptll_135' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_135/targets.tsv
# ⏭️ Skipping controls_gptll_135_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 136 → gen_id 'controls_gptll_136' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_136/targets.tsv
# ⏭️ Skipping controls_gptll_136_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 137 → gen_id 'controls_gptll_137' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_137/targets.tsv
# ⏭️ Skipping controls_gptll_137_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 138 → gen_id 'controls_gptll_138' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_138/targets.tsv
# ⏭️ Skipping controls_gptll_138_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 139 → gen_id 'controls_gptll_139' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_139/targets.tsv
# ⏭️ Skipping controls_gptll_139_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 140 → gen_id 'controls_gptll_140' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_140/targets.tsv
# ⏭️ Skipping controls_gptll_140_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 141 → gen_id 'controls_gptll_141' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_141/targets.tsv
# ⏭️ Skipping controls_gptll_141_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 142 → gen_id 'controls_gptll_142' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_142/targets.tsv
# ⏭️ Skipping controls_gptll_142_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 143 → gen_id 'controls_gptll_143' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_143/targets.tsv
# ⏭️ Skipping controls_gptll_143_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 144 → gen_id 'controls_gptll_144' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_144/targets.tsv
# ⏭️ Skipping controls_gptll_144_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 145 → gen_id 'controls_gptll_145' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_145/targets.tsv
# ⏭️ Skipping controls_gptll_145_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 146 → gen_id 'controls_gptll_146' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_146/targets.tsv
# ⏭️ Skipping controls_gptll_146_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 147 → gen_id 'controls_gptll_147' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_147/targets.tsv
# ⏭️ Skipping controls_gptll_147_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 148 → gen_id 'controls_gptll_148' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_148/targets.tsv
# ⏭️ Skipping controls_gptll_148_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 149 → gen_id 'controls_gptll_149' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_149/targets.tsv
# ⏭️ Skipping controls_gptll_149_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 150 → gen_id 'controls_gptll_150' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_150/targets.tsv
# ⏭️ Skipping controls_gptll_150_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 151 → gen_id 'controls_gptll_151' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_151/targets.tsv
# ⏭️ Skipping controls_gptll_151_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 152 → gen_id 'controls_gptll_152' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_152/targets.tsv
# ⏭️ Skipping controls_gptll_152_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 153 → gen_id 'controls_gptll_153' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_153/targets.tsv
# ⏭️ Skipping controls_gptll_153_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 154 → gen_id 'controls_gptll_154' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_154/targets.tsv
# ⏭️ Skipping controls_gptll_154_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 155 → gen_id 'controls_gptll_155' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_155/targets.tsv
# ⏭️ Skipping controls_gptll_155_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 156 → gen_id 'controls_gptll_156' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_156/targets.tsv
# ⏭️ Skipping controls_gptll_156_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 157 → gen_id 'controls_gptll_157' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_157/targets.tsv
# ⏭️ Skipping controls_gptll_157_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 158 → gen_id 'controls_gptll_158' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_158/targets.tsv
# ⏭️ Skipping controls_gptll_158_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 159 → gen_id 'controls_gptll_159' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_159/targets.tsv
# ⏭️ Skipping controls_gptll_159_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 160 → gen_id 'controls_gptll_160' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_160/targets.tsv
# ⏭️ Skipping controls_gptll_160_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 161 → gen_id 'controls_gptll_161' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_161/targets.tsv
# ⏭️ Skipping controls_gptll_161_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 162 → gen_id 'controls_gptll_162' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_162/targets.tsv
# ⏭️ Skipping controls_gptll_162_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 163 → gen_id 'controls_gptll_163' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_163/targets.tsv
# ⏭️ Skipping controls_gptll_163_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 164 → gen_id 'controls_gptll_164' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_164/targets.tsv
# ⏭️ Skipping controls_gptll_164_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 165 → gen_id 'controls_gptll_165' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_165/targets.tsv
# ⏭️ Skipping controls_gptll_165_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 166 → gen_id 'controls_gptll_166' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_166/targets.tsv
# ⏭️ Skipping controls_gptll_166_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 167 → gen_id 'controls_gptll_167' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_167/targets.tsv
# ⏭️ Skipping controls_gptll_167_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 168 → gen_id 'controls_gptll_168' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_168/targets.tsv
# ⏭️ Skipping controls_gptll_168_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 169 → gen_id 'controls_gptll_169' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_169/targets.tsv
# ⏭️ Skipping controls_gptll_169_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 170 → gen_id 'controls_gptll_170' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_170/targets.tsv
# ⏭️ Skipping controls_gptll_170_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 171 → gen_id 'controls_gptll_171' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_171/targets.tsv
# ⏭️ Skipping controls_gptll_171_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 172 → gen_id 'controls_gptll_172' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_172/targets.tsv
# ⏭️ Skipping controls_gptll_172_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 173 → gen_id 'controls_gptll_173' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_173/targets.tsv
# ⏭️ Skipping controls_gptll_173_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 174 → gen_id 'controls_gptll_174' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_174/targets.tsv
# ⏭️ Skipping controls_gptll_174_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 175 → gen_id 'controls_gptll_175' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_175/targets.tsv
# ⏭️ Skipping controls_gptll_175_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 176 → gen_id 'controls_gptll_176' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_176/targets.tsv
# ⏭️ Skipping controls_gptll_176_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 177 → gen_id 'controls_gptll_177' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_177/targets.tsv
# ⏭️ Skipping controls_gptll_177_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 178 → gen_id 'controls_gptll_178' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_178/targets.tsv
# ⏭️ Skipping controls_gptll_178_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 179 → gen_id 'controls_gptll_179' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_179/targets.tsv
# ⏭️ Skipping controls_gptll_179_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 180 → gen_id 'controls_gptll_180' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_180/targets.tsv
# ⏭️ Skipping controls_gptll_180_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 181 → gen_id 'controls_gptll_181' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_181/targets.tsv
# ⏭️ Skipping controls_gptll_181_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 182 → gen_id 'controls_gptll_182' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_182/targets.tsv
# ⏭️ Skipping controls_gptll_182_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 183 → gen_id 'controls_gptll_183' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_183/targets.tsv
# ⏭️ Skipping controls_gptll_183_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 184 → gen_id 'controls_gptll_184' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_184/targets.tsv
# ⏭️ Skipping controls_gptll_184_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 185 → gen_id 'controls_gptll_185' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_185/targets.tsv
# ⏭️ Skipping controls_gptll_185_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 186 → gen_id 'controls_gptll_186' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_186/targets.tsv
# ⏭️ Skipping controls_gptll_186_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 187 → gen_id 'controls_gptll_187' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_187/targets.tsv
# ⏭️ Skipping controls_gptll_187_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 188 → gen_id 'controls_gptll_188' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_188/targets.tsv
# ⏭️ Skipping controls_gptll_188_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 189 → gen_id 'controls_gptll_189' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_189/targets.tsv
# ⏭️ Skipping controls_gptll_189_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 190 → gen_id 'controls_gptll_190' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_190/targets.tsv
# ⏭️ Skipping controls_gptll_190_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 191 → gen_id 'controls_gptll_191' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_191/targets.tsv
# ⏭️ Skipping controls_gptll_191_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 192 → gen_id 'controls_gptll_192' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_192/targets.tsv
# ⏭️ Skipping controls_gptll_192_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 193 → gen_id 'controls_gptll_193' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_193/targets.tsv
# ⏭️ Skipping controls_gptll_193_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 194 → gen_id 'controls_gptll_194' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_194/targets.tsv
# ⏭️ Skipping controls_gptll_194_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 195 → gen_id 'controls_gptll_195' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_195/targets.tsv
# ⏭️ Skipping controls_gptll_195_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 196 → gen_id 'controls_gptll_196' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_196/targets.tsv
# ⏭️ Skipping controls_gptll_196_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 197 → gen_id 'controls_gptll_197' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_197/targets.tsv
# ⏭️ Skipping controls_gptll_197_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 198 → gen_id 'controls_gptll_198' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_198/targets.tsv
# ⏭️ Skipping controls_gptll_198_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ✅ Index 199 → gen_id 'controls_gptll_199' → /scratch/ggrama/tcrgen/controls/gptll/user_outputs/controls_gptll_199/targets.tsv
# ⏭️ Skipping controls_gptll_199_run_T00000_A0201_GILGFVFTL_0_model_1_model_2_ptm_relaxed_0001.pdb — already computed
# ...
# ✅ gen5_scp-select_204 → RMSD: 3.213 Å
# ✅ Index 205 → gen_id 'gen5_scp-select_205' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_205/targets.tsv
# ✅ gen5_scp-select_205 → RMSD: 0.180 Å
# ✅ Index 206 → gen_id 'gen5_scp-select_206' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_206/targets.tsv
# ✅ gen5_scp-select_206 → RMSD: 2.140 Å
# ✅ Index 207 → gen_id 'gen5_scp-select_207' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_207/targets.tsv
# ✅ gen5_scp-select_207 → RMSD: 3.283 Å
# ✅ Index 208 → gen_id 'gen5_scp-select_208' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_208/targets.tsv
# ✅ gen5_scp-select_208 → RMSD: 5.075 Å
# ✅ Index 209 → gen_id 'gen5_scp-select_209' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_209/targets.tsv
# ✅ gen5_scp-select_209 → RMSD: 3.320 Å
# ✅ Index 210 → gen_id 'gen5_scp-select_210' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_210/targets.tsv
# ✅ gen5_scp-select_210 → RMSD: 2.131 Å
# ✅ Index 211 → gen_id 'gen5_scp-select_211' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_211/targets.tsv
# ✅ gen5_scp-select_211 → RMSD: 3.388 Å
# ✅ Index 212 → gen_id 'gen5_scp-select_212' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_212/targets.tsv
# ✅ gen5_scp-select_212 → RMSD: 3.124 Å
# ✅ Index 213 → gen_id 'gen5_scp-select_213' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_213/targets.tsv
# ✅ gen5_scp-select_213 → RMSD: 0.230 Å
# ✅ Index 214 → gen_id 'gen5_scp-select_214' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_214/targets.tsv
# ✅ gen5_scp-select_214 → RMSD: 0.212 Å
# ✅ Index 215 → gen_id 'gen5_scp-select_215' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_215/targets.tsv
# ✅ gen5_scp-select_215 → RMSD: 3.159 Å
# ✅ Index 216 → gen_id 'gen5_scp-select_216' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_216/targets.tsv
# ✅ gen5_scp-select_216 → RMSD: 9.282 Å
# ✅ Index 217 → gen_id 'gen5_scp-select_217' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_217/targets.tsv
# ✅ gen5_scp-select_217 → RMSD: 1.647 Å
# ✅ Index 218 → gen_id 'gen5_scp-select_218' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_218/targets.tsv
# ✅ gen5_scp-select_218 → RMSD: 4.849 Å
# ✅ Index 219 → gen_id 'gen5_scp-select_219' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_219/targets.tsv
# ✅ gen5_scp-select_219 → RMSD: 3.241 Å
# ✅ Index 220 → gen_id 'gen5_scp-select_220' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_220/targets.tsv
# ✅ gen5_scp-select_220 → RMSD: 4.811 Å
# ✅ Index 221 → gen_id 'gen5_scp-select_221' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_221/targets.tsv
# ✅ gen5_scp-select_221 → RMSD: 3.104 Å
# ✅ Index 222 → gen_id 'gen5_scp-select_222' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_222/targets.tsv
# ✅ gen5_scp-select_222 → RMSD: 7.642 Å
# ✅ Index 223 → gen_id 'gen5_scp-select_223' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_223/targets.tsv
# ✅ gen5_scp-select_223 → RMSD: 6.194 Å
# ✅ Index 224 → gen_id 'gen5_scp-select_224' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_224/targets.tsv
# ✅ gen5_scp-select_224 → RMSD: 1.969 Å
# ✅ Index 225 → gen_id 'gen5_scp-select_225' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_225/targets.tsv
# ✅ gen5_scp-select_225 → RMSD: 2.060 Å
# ✅ Index 226 → gen_id 'gen5_scp-select_226' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_226/targets.tsv
# ✅ gen5_scp-select_226 → RMSD: 1.628 Å
# ✅ Index 227 → gen_id 'gen5_scp-select_227' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_227/targets.tsv
# ✅ gen5_scp-select_227 → RMSD: 0.136 Å
# ✅ Index 228 → gen_id 'gen5_scp-select_228' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_228/targets.tsv
# ✅ gen5_scp-select_228 → RMSD: 0.237 Å
# ✅ Index 229 → gen_id 'gen5_scp-select_229' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_229/targets.tsv
# ✅ gen5_scp-select_229 → RMSD: 1.409 Å
# ✅ Index 230 → gen_id 'gen5_scp-select_230' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_230/targets.tsv
# ✅ gen5_scp-select_230 → RMSD: 3.205 Å
# ✅ Index 231 → gen_id 'gen5_scp-select_231' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_231/targets.tsv
# ✅ gen5_scp-select_231 → RMSD: 4.513 Å
# ✅ Index 232 → gen_id 'gen5_scp-select_232' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_232/targets.tsv
# ✅ gen5_scp-select_232 → RMSD: 1.649 Å
# ✅ Index 233 → gen_id 'gen5_scp-select_233' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_233/targets.tsv
# ✅ gen5_scp-select_233 → RMSD: 2.098 Å
# ✅ Index 234 → gen_id 'gen5_scp-select_234' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_234/targets.tsv
# ✅ gen5_scp-select_234 → RMSD: 3.159 Å
# ✅ Index 235 → gen_id 'gen5_scp-select_235' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_235/targets.tsv
# ✅ gen5_scp-select_235 → RMSD: 5.084 Å
# ✅ Index 236 → gen_id 'gen5_scp-select_236' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_236/targets.tsv
# ✅ gen5_scp-select_236 → RMSD: 4.884 Å
# ✅ Index 237 → gen_id 'gen5_scp-select_237' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_237/targets.tsv
# ✅ gen5_scp-select_237 → RMSD: 0.144 Å
# ✅ Index 238 → gen_id 'gen5_scp-select_238' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_238/targets.tsv
# ✅ gen5_scp-select_238 → RMSD: 3.363 Å
# ✅ Index 239 → gen_id 'gen5_scp-select_239' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_239/targets.tsv
# ✅ gen5_scp-select_239 → RMSD: 3.262 Å
# ✅ Index 240 → gen_id 'gen5_scp-select_240' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_240/targets.tsv
# ✅ gen5_scp-select_240 → RMSD: 1.983 Å
# ✅ Index 241 → gen_id 'gen5_scp-select_241' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_241/targets.tsv
# ✅ gen5_scp-select_241 → RMSD: 2.020 Å
# ✅ Index 242 → gen_id 'gen5_scp-select_242' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_242/targets.tsv
# ✅ gen5_scp-select_242 → RMSD: 0.249 Å
# ✅ Index 243 → gen_id 'gen5_scp-select_243' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_243/targets.tsv
# ✅ gen5_scp-select_243 → RMSD: 1.678 Å
# ✅ Index 244 → gen_id 'gen5_scp-select_244' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_244/targets.tsv
# ✅ gen5_scp-select_244 → RMSD: 4.849 Å
# ✅ Index 245 → gen_id 'gen5_scp-select_245' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_245/targets.tsv
# ✅ gen5_scp-select_245 → RMSD: 0.189 Å
# ✅ Index 246 → gen_id 'gen5_scp-select_246' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_246/targets.tsv
# ✅ gen5_scp-select_246 → RMSD: 3.272 Å
# ✅ Index 247 → gen_id 'gen5_scp-select_247' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_247/targets.tsv
# ✅ gen5_scp-select_247 → RMSD: 0.192 Å
# ✅ Index 248 → gen_id 'gen5_scp-select_248' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_248/targets.tsv
# ✅ gen5_scp-select_248 → RMSD: 0.259 Å
# ✅ Index 249 → gen_id 'gen5_scp-select_249' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_249/targets.tsv
# ✅ gen5_scp-select_249 → RMSD: 1.927 Å
# ✅ Index 250 → gen_id 'gen5_scp-select_250' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_250/targets.tsv
# ✅ gen5_scp-select_250 → RMSD: 6.429 Å
# ✅ Index 251 → gen_id 'gen5_scp-select_251' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_251/targets.tsv
# ✅ gen5_scp-select_251 → RMSD: 5.091 Å
# ✅ Index 252 → gen_id 'gen5_scp-select_252' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_252/targets.tsv
# ✅ gen5_scp-select_252 → RMSD: 4.045 Å
# ✅ Index 253 → gen_id 'gen5_scp-select_253' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_253/targets.tsv
# ✅ gen5_scp-select_253 → RMSD: 3.283 Å
# ✅ Index 254 → gen_id 'gen5_scp-select_254' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_254/targets.tsv
# ✅ gen5_scp-select_254 → RMSD: 6.531 Å
# ✅ Index 255 → gen_id 'gen5_scp-select_255' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_255/targets.tsv
# ✅ gen5_scp-select_255 → RMSD: 1.860 Å
# ✅ Index 256 → gen_id 'gen5_scp-select_256' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_256/targets.tsv
# ✅ gen5_scp-select_256 → RMSD: 0.133 Å
# ✅ Index 257 → gen_id 'gen5_scp-select_257' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_257/targets.tsv
# ✅ gen5_scp-select_257 → RMSD: 0.274 Å
# ✅ Index 258 → gen_id 'gen5_scp-select_258' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_258/targets.tsv
# ✅ gen5_scp-select_258 → RMSD: 0.159 Å
# ✅ Index 259 → gen_id 'gen5_scp-select_259' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_259/targets.tsv
# ✅ gen5_scp-select_259 → RMSD: 3.247 Å
# ✅ Index 260 → gen_id 'gen5_scp-select_260' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_260/targets.tsv
# ✅ gen5_scp-select_260 → RMSD: 3.063 Å
# ✅ Index 261 → gen_id 'gen5_scp-select_261' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_261/targets.tsv
# ✅ gen5_scp-select_261 → RMSD: 0.192 Å
# ✅ Index 262 → gen_id 'gen5_scp-select_262' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_262/targets.tsv
# ✅ gen5_scp-select_262 → RMSD: 3.121 Å
# ✅ Index 263 → gen_id 'gen5_scp-select_263' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_263/targets.tsv
# ✅ gen5_scp-select_263 → RMSD: 2.167 Å
# ✅ Index 264 → gen_id 'gen5_scp-select_264' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_264/targets.tsv
# ✅ gen5_scp-select_264 → RMSD: 0.252 Å
# ✅ Index 265 → gen_id 'gen5_scp-select_265' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_265/targets.tsv
# ✅ gen5_scp-select_265 → RMSD: 5.126 Å
# ✅ Index 266 → gen_id 'gen5_scp-select_266' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_266/targets.tsv
# ✅ gen5_scp-select_266 → RMSD: 5.094 Å
# ✅ Index 267 → gen_id 'gen5_scp-select_267' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_267/targets.tsv
# ✅ gen5_scp-select_267 → RMSD: 4.890 Å
# ✅ Index 268 → gen_id 'gen5_scp-select_268' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_268/targets.tsv
# ✅ gen5_scp-select_268 → RMSD: 7.776 Å
# ✅ Index 269 → gen_id 'gen5_scp-select_269' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_269/targets.tsv
# ✅ gen5_scp-select_269 → RMSD: 1.935 Å
# ✅ Index 270 → gen_id 'gen5_scp-select_270' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_270/targets.tsv
# ✅ gen5_scp-select_270 → RMSD: 3.872 Å
# ✅ Index 271 → gen_id 'gen5_scp-select_271' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_271/targets.tsv
# ✅ gen5_scp-select_271 → RMSD: 3.205 Å
# ✅ Index 272 → gen_id 'gen5_scp-select_272' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_272/targets.tsv
# ✅ gen5_scp-select_272 → RMSD: 0.134 Å
# ✅ Index 273 → gen_id 'gen5_scp-select_273' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_273/targets.tsv
# ✅ gen5_scp-select_273 → RMSD: 7.712 Å
# ✅ Index 274 → gen_id 'gen5_scp-select_274' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_274/targets.tsv
# ✅ gen5_scp-select_274 → RMSD: 3.373 Å
# ✅ Index 275 → gen_id 'gen5_scp-select_275' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_275/targets.tsv
# ✅ gen5_scp-select_275 → RMSD: 2.115 Å
# ✅ Index 276 → gen_id 'gen5_scp-select_276' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_276/targets.tsv
# ✅ gen5_scp-select_276 → RMSD: 0.240 Å
# ✅ Index 277 → gen_id 'gen5_scp-select_277' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_277/targets.tsv
# ✅ gen5_scp-select_277 → RMSD: 0.144 Å
# ✅ Index 278 → gen_id 'gen5_scp-select_278' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_278/targets.tsv
# ✅ gen5_scp-select_278 → RMSD: 0.145 Å
# ✅ Index 279 → gen_id 'gen5_scp-select_279' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_279/targets.tsv
# ✅ gen5_scp-select_279 → RMSD: 2.133 Å
# ✅ Index 280 → gen_id 'gen5_scp-select_280' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_280/targets.tsv
# ✅ gen5_scp-select_280 → RMSD: 2.120 Å
# ✅ Index 281 → gen_id 'gen5_scp-select_281' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_281/targets.tsv
# ✅ gen5_scp-select_281 → RMSD: 2.148 Å
# ✅ Index 282 → gen_id 'gen5_scp-select_282' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_282/targets.tsv
# ✅ gen5_scp-select_282 → RMSD: 0.295 Å
# ✅ Index 283 → gen_id 'gen5_scp-select_283' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_283/targets.tsv
# ✅ gen5_scp-select_283 → RMSD: 4.682 Å
# ✅ Index 284 → gen_id 'gen5_scp-select_284' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_284/targets.tsv
# ✅ gen5_scp-select_284 → RMSD: 4.515 Å
# ✅ Index 285 → gen_id 'gen5_scp-select_285' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_285/targets.tsv
# ✅ gen5_scp-select_285 → RMSD: 4.783 Å
# ✅ Index 286 → gen_id 'gen5_scp-select_286' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_286/targets.tsv
# ✅ gen5_scp-select_286 → RMSD: 3.139 Å
# ✅ Index 287 → gen_id 'gen5_scp-select_287' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_287/targets.tsv
# ✅ gen5_scp-select_287 → RMSD: 1.968 Å
# ✅ Index 288 → gen_id 'gen5_scp-select_288' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_288/targets.tsv
# ✅ gen5_scp-select_288 → RMSD: 2.074 Å
# ✅ Index 289 → gen_id 'gen5_scp-select_289' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_289/targets.tsv
# ✅ gen5_scp-select_289 → RMSD: 7.876 Å
# ✅ Index 290 → gen_id 'gen5_scp-select_290' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_290/targets.tsv
# ✅ gen5_scp-select_290 → RMSD: 2.901 Å
# ✅ Index 291 → gen_id 'gen5_scp-select_291' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_291/targets.tsv
# ✅ gen5_scp-select_291 → RMSD: 3.242 Å
# ✅ Index 292 → gen_id 'gen5_scp-select_292' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_292/targets.tsv
# ✅ gen5_scp-select_292 → RMSD: 0.157 Å
# ✅ Index 293 → gen_id 'gen5_scp-select_293' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_293/targets.tsv
# ✅ gen5_scp-select_293 → RMSD: 2.106 Å
# ✅ Index 294 → gen_id 'gen5_scp-select_294' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_294/targets.tsv
# ✅ gen5_scp-select_294 → RMSD: 0.290 Å
# ✅ Index 295 → gen_id 'gen5_scp-select_295' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_295/targets.tsv
# ✅ gen5_scp-select_295 → RMSD: 3.232 Å
# ✅ Index 296 → gen_id 'gen5_scp-select_296' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_296/targets.tsv
# ✅ gen5_scp-select_296 → RMSD: 1.977 Å
# ✅ Index 297 → gen_id 'gen5_scp-select_297' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_297/targets.tsv
# ✅ gen5_scp-select_297 → RMSD: 1.673 Å
# ✅ Index 298 → gen_id 'gen5_scp-select_298' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_298/targets.tsv
# ✅ gen5_scp-select_298 → RMSD: 4.160 Å
# ✅ Index 299 → gen_id 'gen5_scp-select_299' → /scratch/ggrama/tcrgen/gen5/scp-select/user_outputs/gen5_scp-select_299/targets.tsv
# ✅ gen5_scp-select_299 → RMSD: 0.252 Å
#
# 🎉 Done. Saved 2700 RMSDs to: /home/ggrama/tcrgen/cdr3b_epitope_rmsd_flexible.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# === Load and clean
df = pd.read_csv("/home/ggrama/tcrgen/cdr3b_epitope_rmsd_flexible.csv")
df = df[df["rmsd_flexible"] >= 0]  # just in case

# === Order groups by median RMSD
group_order = (
    df.groupby("group_dir")["rmsd_flexible"]
    .median()
    .sort_values()
    .index.tolist()
)

# === Plot
plt.figure(figsize=(12, len(group_order) * 0.5))
sns.set(style="whitegrid")

sns.violinplot(
    data=df,
    y="group_dir",
    x="rmsd_flexible",
    order=group_order,
    inner="quartile",
    scale="width",
    linewidth=1.2,
    cut=0  # prevents violin tails from extending past data
)

plt.title("CDR3β Flexible RMSD by Group")
plt.xlabel("RMSD (Å)")
plt.ylabel("Group")
plt.xlim(left=0)  # eliminate confusing negatives
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3308129/1610897963.py:21: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
